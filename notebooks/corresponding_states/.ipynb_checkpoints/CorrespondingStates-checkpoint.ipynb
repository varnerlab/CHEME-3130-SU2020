# %% [markdown]
# ## Test the Theory of Corresponding States using data for [Methanol](https://webbook.nist.gov/cgi/cbook.cgi?ID=C67561&Mask=4) and [Cyclohexane](https://webbook.nist.gov/cgi/cbook.cgi?ID=C110827&Mask=4)

# %%
# includes -
using PyPlot
using DataFrames
using CSV

# load my code -
include("./code/Compressibility.jl")

# Critical parameters -
Tc_methannol = 513.0 # units: K
Pc_methanol = 8.1 # MPa

Tc_cyclohexane = 554.0 # units: K
Pc_cyclohexane = 4.07 # MPa

Tc_hexane = 507.6 # units: K
Pc_hexane = 3.02 # MPa

Tc_benzene = 562.0 # units: K
Pc_benzene = 4.89 # units: MPa

Tc_propane = 369.9 # units: K
Pc_propane = 4.25 # units: MPa

# === Tr = 1.0 ===========================================================
# Load Methanol data -
methanol_data_table = CSV.read("Methanol-NIST-514K.txt",delim='\t');

# Load the Cyclohexane data -
cyclohexane_data_table = CSV.read("Cyclohexane-NIST-555K.txt",delim='\t');

# Compute the compressibility -
(Z_methanol,P_methanol) = calculateCompressibility(methanol_data_table)
(Z_cyclohexane,P_cyclohexane) = calculateCompressibility(cyclohexane_data_table)

# Compute the reduced pressure -
P_methanol_r = (P_methanol).*(1/Pc_methanol)
P_cyclohexane_r = (P_cyclohexane).*(1/Pc_cyclohexane)

# Plot -
plot(P_methanol_r,Z_methanol,"r",label="Methanol Tr = 1.0");
plot(P_cyclohexane_r,Z_cyclohexane,"b",label="Cyclohexane Tr = 1.0");

# label the axis -
xlabel(L"Reduced pressure P$_{r}$",fontsize=16);
ylabel(L"Compressibility factor $Z$",fontsize=16);
legend(loc="upper right");
# ========================================================================
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# === Tr = 1.2 ===========================================================
# Load Methanol data -
methanol_data_table = CSV.read("Methanol-NIST-615K.txt",delim='\t');

# Load the Cyclohexane data -
cyclohexane_data_table = CSV.read("Cyclohexane-NIST-664K.txt",delim='\t');

# Compute the compressibility -
(Z_methanol,P_methanol) = calculateCompressibility(methanol_data_table)
(Z_cyclohexane,P_cyclohexane) = calculateCompressibility(cyclohexane_data_table)

# Compute the reduced pressure -
P_methanol_r = (P_methanol).*(1/Pc_methanol)
P_cyclohexane_r = (P_cyclohexane).*(1/Pc_cyclohexane)

# Plot -
plot(P_methanol_r,Z_methanol,"r",label="Methanol Tr = 1.2");
plot(P_cyclohexane_r,Z_cyclohexane,"b",label="Cyclohexane Tr = 1.2");

# label the axis -
xlabel(L"Reduced pressure P$_{r}$",fontsize=16);
ylabel(L"Compressibility factor $Z$",fontsize=16);
legend(loc="upper right");
# ========================================================================
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# === Tr = 1.0 ===========================================================
# Load Methanol data -
benzene_data_table = CSV.read("Benzene-NIST-563K.txt",delim='\t');

# Load the Cyclohexane data -
cyclohexane_data_table = CSV.read("Cyclohexane-NIST-555K.txt",delim='\t');

# Compute the compressibility -
(Z_benzene,P_benzene) = calculateCompressibility(benzene_data_table)
(Z_cyclohexane,P_cyclohexane) = calculateCompressibility(cyclohexane_data_table)

# Compute the reduced pressure -
P_benzene_r = (P_benzene).*(1/Pc_benzene)
P_cyclohexane_r = (P_cyclohexane).*(1/Pc_cyclohexane)

# Plot -
plot(P_benzene_r,Z_benzene,"r",label="Benzene Tr = 1.0");
plot(P_cyclohexane_r,Z_cyclohexane,"b",label="Cyclohexane Tr = 1.0");

# label the axis -
xlabel(L"Reduced pressure P$_{r}$",fontsize=16);
ylabel(L"Compressibility factor $Z$",fontsize=16);
legend(loc="upper right");
# ========================================================================
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# === Tr = 1.0 ===========================================================
# Load hexane data -
hexane_data_table = CSV.read("Hexane-NIST-507K.txt",delim='\t');

# Load the Cyclohexane data -
cyclohexane_data_table = CSV.read("Cyclohexane-NIST-555K.txt",delim='\t');

# Compute the compressibility -
(Z_hexane,P_hexane) = calculateCompressibility(hexane_data_table)
(Z_cyclohexane,P_cyclohexane) = calculateCompressibility(cyclohexane_data_table)

# Compute the reduced pressure -
P_hexane_r = (P_hexane).*(1/Pc_hexane)
P_cyclohexane_r = (P_cyclohexane).*(1/Pc_cyclohexane)

# Plot -
plot(P_hexane_r,Z_hexane,"r",label="Hexane Tr = 1.0");
plot(P_cyclohexane_r,Z_cyclohexane,"b",label="Cyclohexane Tr = 1.0");

# label the axis -
xlabel(L"Reduced pressure P$_{r}$",fontsize=16);
ylabel(L"Compressibility factor $Z$",fontsize=16);
legend(loc="upper right");
# ========================================================================
# Out:
# UndefVarError: P_hexane not defined
#
# Stacktrace:
#  [1] top-level scope at In[21]:11
